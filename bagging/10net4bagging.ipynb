# %% [markdown]
# <a href="https://colab.research.google.com/github/KORALLLL/summer_practice/blob/main/bagging/10net4bagging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tenth FC NN for bagging

# %% [markdown]
# ## Configuration

# %% [markdown]
# датасет: MNIST[54000:60000]
#
# размер обучающей выборки: 6000(сырого) + 14000(аугментаций)
#
# размер тестирующей выборки: 10000
#
# количество скрытых слоёв: 2
#
# количество нейронов в скрытых слояx: 250
#
# функция активации: сигмоида
#
# функция потерь: кросс энтропия
#
# оптимизатор: SGD
#
# скорость обучение: 0.01
#
# импульс: 0.7
#
# размер батча: 2000
#
# количество эпох: 1000

# %% [markdown]
# ## Prepairing data

# %%
start = 54000
stop = 60000

import torch
import torchvision.datasets
import torchvision.transforms
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm
from PIL import Image
from copy import deepcopy

def augmentation(old_image, label):
  old_image = Image.fromarray(old_image.numpy(), mode='L')

  rotater = torchvision.transforms.RandomRotation(degrees = (-15, 15))
  h_flipper = torchvision.transforms.RandomHorizontalFlip(p=1) #only for 08
  v_flipper = torchvision.transforms.RandomVerticalFlip(p=1) #only for 08
  shifter = torchvision.transforms.RandomAffine(0, translate = (2/28,2/28))
  compressor = torchvision.transforms.RandomAffine(0, scale = (0.8, 0.9))
  stratcher = torchvision.transforms.RandomAffine(0, scale = (1.05, 1.1))

  seed1 = random.randint(0, 3)
  if label == 0 or label == 8:
    if seed1 == 0:
      image = old_image
    elif seed1 == 1:
      image = h_flipper(old_image)
    elif seed1 == 2:
      image = v_flipper(old_image)
    else:
      image = h_flipper(v_flipper(old_image))
  else:
    image = old_image

  seed = random.randint(0,10)
  if seed == 0: #rot
    new_image = rotater(image)
  elif seed == 1: #shift
    new_image = shifter(image)
  elif seed == 2: #comp
    new_image = compressor(image)
  elif seed == 3: #str
    new_image = stratcher(image)
  elif seed == 4: #rot+shift
    new_image = rotater(shifter(image))
  elif seed == 5: #rot+comp
    new_image = rotater(compressor(image))
  elif seed == 6: #rot+str
    new_image = rotater(stratcher(image))
  elif seed == 7: #shift+comp
    new_image = shifter(compressor(image))
  elif seed == 8: #shift+stretch
    new_image = shifter(stratcher(image))
  elif seed == 9: #rot+shift+comp
    new_image = rotater(shifter(compressor(image)))
  elif seed == 10: #tor+shift+stretch
    new_image = rotater(shifter(stratcher(image)))

  new_image = torchvision.transforms.ToTensor()(new_image)
  new_image = new_image.squeeze()
  return(new_image)


MNIST_train = torchvision.datasets.MNIST('./', download = True, train = True)
MNIST_test = torchvision.datasets.MNIST('./', download = True, train = False)

x_train = MNIST_train.data[start:stop]
y_train = MNIST_train.targets[start:stop]

temp_x_train, temp_train_label = [], []
random_indexes = random.choices(range(0,6000), k=14000)

for i in random_indexes:
  image, label = x_train[i], y_train[i]
  new_image = augmentation(image, label)
  temp_x_train.append(new_image)
  temp_train_label.append(label)

temp_x_train = torch.stack(temp_x_train)
temp_train_label = torch.stack(temp_train_label)

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

x_train = torch.cat([x_train, temp_x_train], dim = 0).float().reshape([-1,28*28]).to(device)
y_train = torch.cat([y_train, temp_train_label], dim = 0).to(device)
x_test = MNIST_test.data.float().reshape([-1, 28*28]).to(device)
y_test = MNIST_test.targets.to(device)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 168414083.93it/s]
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 42698517.39it/s]
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 32893813.51it/s]
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 3733933.51it/s]
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw

# %% [markdown]
# ## Configuration net

# %%
class MNISTNet(torch.nn.Module):
  def __init__(self):
    super(MNISTNet, self).__init__()
    self.fc1 = torch.nn.Linear(28*28, 250)
    self.act1 = torch.nn.Sigmoid()
    self.fc2 = torch.nn.Linear(250,10)

  def forward(self, x):
    x = self.fc1(x)
    x = self.act1(x)
    x = self.fc2(x)
    return x

# %% [markdown]
# ## Hyperparameters

# %%
loss = torch.nn.CrossEntropyLoss()
batch_size = 2000

# %% [markdown]
# ## Test learning on 5000 epoch

# %%
net = MNISTNet().to(device)
optimizer = torch.optim.SGD(net.parameters(), lr = 0.01, momentum = 0.7)


train_acc, test_acc = [], []
train_loss, test_loss  = [], []

for epoch in tqdm(range(5000), desc = 'обучение'):
  order = np.random.permutation(len(x_train))

  for start_index in range(0, len(x_train), batch_size):
    optimizer.zero_grad()

    batch_indexes = order[start_index:start_index+batch_size]

    x_train_batch = x_train[batch_indexes]
    y_train_batch = y_train[batch_indexes]

    pred = net.forward(x_train_batch)

    loss_val = loss(pred, y_train_batch)
    loss_val.backward()

    optimizer.step()

  train_preds = net.forward(x_train)
  test_preds = net.forward(x_test)

  train_acc.append((train_preds.argmax(dim=1) == y_train).float().mean().cpu().data)
  test_acc.append((test_preds.argmax(dim=1) == y_test).float().mean().cpu().data)

  train_loss.append(loss(train_preds, y_train).item())
  test_loss.append(loss(test_preds, y_test).item())
# Out:
# <ipython-input-4-da81385a24e3>:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in tqdm(range(5000), desc = 'обучение'):
# обучение:   0%|          | 0/5000 [00:00<?, ?it/s]

# %%
plt.figure(figsize = (18.0, 6.0))
plt.plot(range(5000), train_acc, c='orange', label = 'train')
plt.plot(range(5000), test_acc, c = 'purple', label = 'test')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.xlim(100, 5000)
plt.ylim(0.8, 0.964)
plt.title('accuracy')
plt.legend(loc = 'lower right')

# %%
plt.figure(figsize = (16.0, 6.0))
plt.plot(range(5000), train_loss, c='orange', label = 'train loss')
plt.plot(range(5000), test_loss, c = 'purple', label = 'test loss')
plt.title('Loss history')
plt.legend(loc = 'upper right')
plt.xlabel('epoch')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ## Learning model

# %%
best_acc = 0.0
best_state = None

for experiment in tqdm(range(200), desc = 'Эксперимент'):
  net = MNISTNet().to(device)
  optimizer = torch.optim.RMSprop(net.parameters(), lr = 0.001)

  for epoch in tqdm(range(1000), desc = 'Обучение'):
    order = np.random.permutation(len(x_train))

    for start_index in range(0, len(x_train), batch_size):
      optimizer.zero_grad()

      batch_indexes = order[start_index:start_index+batch_size]

      x_train_batch = x_train[batch_indexes]
      y_train_batch = y_train[batch_indexes]

      pred = net.forward(x_train_batch)

      loss_val = loss(pred, y_train_batch)
      loss_val.backward()

      optimizer.step()

  test_preds = net.forward(x_test)

  cur_acc = ((test_preds.argmax(dim=1) == y_test).float().mean().cpu().data)
  print(cur_acc)

  if cur_acc > best_acc:
    best_acc = cur_acc
    best_state = deepcopy(net.state_dict())
# Out:
# <ipython-input-7-28cf353df704>:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for experiment in tqdm(range(200), desc = 'Эксперимент'):
# Эксперимент:   0%|          | 0/200 [00:00<?, ?it/s]
# <ipython-input-7-28cf353df704>:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for epoch in tqdm(range(1000), desc = 'Обучение'):
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9566)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9572)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9590)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9584)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9585)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9587)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9594)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9569)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9575)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9600)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9535)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9584)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9591)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9567)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9593)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9564)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9597)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9586)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9576)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9604)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9586)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9562)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9578)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9599)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9586)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9599)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9594)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9576)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9587)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9599)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9592)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9586)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9589)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9600)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9553)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9568)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9577)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9580)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9589)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9575)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9569)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9617)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9581)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9603)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9586)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9580)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9588)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9584)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9573)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9606)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9576)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9577)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9589)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9580)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9585)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9606)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9581)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9589)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9570)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9578)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9584)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9593)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9579)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9588)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9585)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9563)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9574)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9592)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9566)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9602)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9579)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9592)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9598)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9578)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9574)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9584)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9582)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9575)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9582)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9605)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9598)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9581)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9588)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9590)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9582)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9568)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9580)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9597)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9574)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9582)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9574)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9595)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9561)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9573)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9595)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9609)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9575)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9574)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9583)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9581)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9578)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9567)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9579)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9593)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9573)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9606)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9561)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9600)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9583)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9589)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9600)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9586)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9563)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9592)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9601)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9597)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9585)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9575)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9560)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9566)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9555)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9598)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9585)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9578)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9590)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9583)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9561)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9593)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9577)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9590)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9569)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9553)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9573)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9600)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9584)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9596)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9595)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9553)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9596)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9597)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9581)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9579)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9589)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9557)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9596)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9581)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9582)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9587)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9589)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9574)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9565)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9582)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9584)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9590)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9580)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9589)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9597)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9573)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9602)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9582)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9576)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9596)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9579)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9581)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9593)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9585)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9570)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9583)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9601)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9597)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9596)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9594)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9595)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9573)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9595)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9581)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9609)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9584)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9559)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9595)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9593)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9590)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9586)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9562)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9595)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9582)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9580)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9614)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9580)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9573)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9598)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9585)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9572)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9580)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9570)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9601)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9587)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9588)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9569)
# Обучение:   0%|          | 0/1000 [00:00<?, ?it/s]
# tensor(0.9597)

# %%
torch.save(best_state, 'parameters_10net4bagging.pth')
net = MNISTNet().to(device)
net.load_state_dict(torch.load('parameters_10net4bagging.pth'))
test_preds = net.forward(x_test)
print(((test_preds.argmax(dim=1) == y_test).float().mean().cpu().data))
# Out:
# tensor(0.9617)
